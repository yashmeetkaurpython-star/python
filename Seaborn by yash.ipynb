# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
df=sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True, fmt='.2f')
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True, fmt='.2f',vmin=True)
# Out:
# <Axes: >

# %%
sns.jointplot(data=df)

# %%
sns.jointplot(data=df,x="total_bill",y="tip")

# %%
sns.jointplot(data=df,x="total_bill",y="tip",hue="sex")

# %%
sns.jointplot(data=df,x="total_bill",y="tip",hue="sex",kind="kde")

# %%
sns.jointplot(data=df,x="total_bill",y="tip",kind="reg")

# %%
sns.jointplot(data=df,x="total_bill",y="tip",kind="hist")

# %%
sns.jointplot(data=df,x="total_bill",y="tip",kind="hex")

# %%
sns.jointplot(data=df,x="total_bill",y="tip",kind="hex",color="red")

# %%
sns.jointplot(data=df,x="total_bill",y="tip",kind="hex",color="red",palette="True")

# %%
sns.pairplot(data=df)

# %%
sns.pairplot(data=df,hue="sex")

# %%
sns.histplot(data=df)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data=df,x="total_bill",y="tip",hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.histplot(data=df,y="total_bill",hue="sex")
# Out:
# <Axes: xlabel='Count', ylabel='total_bill'>

# %%
sns.histplot(data=df,x="tip",hue="sex")
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=df,y="total_bill",hue="sex",kde="True")
# Out:
# <Axes: xlabel='Count', ylabel='total_bill'>

# %%
sns.histplot(data=df,y="total_bill",hue="sex",kde=True,multiple="stack")
# Out:
# <Axes: xlabel='Count', ylabel='total_bill'>

# %%
sns.histplot(data=df,y="total_bill",hue="sex",kde=True,multiple="layer")
# Out:
# <Axes: xlabel='Count', ylabel='total_bill'>

# %%
sns.histplot(data=df,y="total_bill",hue="sex",kde=True,multiple="fill")
# Out:
# <Axes: xlabel='Count', ylabel='total_bill'>

# %%
sns.histplot(data=df,x="total_bill",hue="sex",kde=True,element="step")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=df,x="total_bill",hue="sex",kde=True,element="poly")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.dogplot()

# %%
sns.catplot(data=df)

# %%
sns.catplot(data=df,x="total_bill",y="tip",hue="sex")

# %%
sns.catplot(data=df,x="total_bill",y="tip",hue="sex",kind='strip')

# %%
sns.boxplot(data=df,x="total_bill",y="tip",order=None,)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
sns.violinplot(data=df)
# Out:
# <Axes: >
