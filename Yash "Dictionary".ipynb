# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
d1={"Name":"Zubair","Father_Name":"Fayaz_Ah","D.O.B":1997,
"Salary":80000,"Dept":"CSE"}

# %%
d1
# Out:
# {'Name': 'Zubair',
#  'Father_Name': 'Fayaz_Ah',
#  'D.O.B': 1997,
#  'Salary': 80000,
#  'Dept': 'CSE'}

# %%
d1['Name']="kubair"
print(d1)
# Out:
# {'Name': 'kubair', 'Father_Name': 'Fayaz_Ah', 'D.O.B': 1997, 'Salary': 80000, 'Dept': 'CSE'}

# %%
d2={'Name': 'Zubair',
 'Father_Name': 'Fayaz_Ah',
 'D.O.B': 1997,
 'Salary': 80000,
 'Dept': 'CSE',"Name":"ABC"}

# %%
d2
# Out:
# {'Name': 'ABC',
#  'Father_Name': 'Fayaz_Ah',
#  'D.O.B': 1997,
#  'Salary': 80000,
#  'Dept': 'CSE'}

# %%
d3={1:"yash"}

# %%
d3={(1,2,3):"yash"}

# %%
d3
# Out:
# {(1, 2, 3): 'yash'}

# %%
d={'Name': 'ABC',
 'Father_Name': 'Fayaz_Ah',
 'D.O.B': 1997,
 'Salary': 80000,
 'Dept': 'CSE'}

# %%
d
# Out:
# {'Name': 'ABC',
#  'Father_Name': 'Fayaz_Ah',
#  'D.O.B': 1997,
#  'Salary': 80000,
#  'Dept': 'CSE'}

# %%
d.get('Salary')
# Out:
# 80000

# %%
d['Salary']
# Out:
# 80000

# %%
d.items()
# Out:
# dict_items([('Name', 'ABC'), ('Father_Name', 'Fayaz_Ah'), ('D.O.B', 1997), ('Salary', 80000), ('Dept', 'CSE')])

# %%
d.keys()
# Out:
# dict_keys(['Name', 'Father_Name', 'D.O.B', 'Salary', 'Dept'])

# %%
d.values()
# Out:
# dict_values(['ABC', 'Fayaz_Ah', 1997, 80000, 'CSE'])

# %%
s=("yash","dipreet")
s1=1
dict.fromkeys(s,s1)
# Out:
# {'yash': 1, 'dipreet': 1}

# %%
d.pop('Name')
# Out:
# 'ABC'

# %%
d
# Out:
# {'Father_Name': 'Fayaz_Ah', 'D.O.B': 1997, 'Salary': 80000, 'Dept': 'CSE'}

# %%
d.popitem()
# Out:
# ('Dept', 'CSE')

# %%
d
# Out:
# {'Father_Name': 'Fayaz_Ah', 'D.O.B': 1997, 'Salary': 80000}

# %%
d.setdefault('D.O.B',2000)
# Out:
# 1997

# %%
d.update({'D.O.B':2000})

# %%
d
# Out:
# {'Father_Name': 'Fayaz_Ah', 'D.O.B': 2000, 'Salary': 80000}

# %%
d.setdefault("Name","Yash")
# Out:
# 'Yash'

# %%
d.update({"Role":"Teacher"})

# %%
d
# Out:
# {'Father_Name': 'Fayaz_Ah',
#  'D.O.B': 2000,
#  'Salary': 80000,
#  'Name': 'Yash',
#  'Role': 'Teacher'}

# %%
d={'Fruits':["Banana","Orange","Apple","Grapes"],
   'Size':[20,30,40,60],
   'Weight':[80,20,40,25],
   'Color':['Yellow','Orange','Red','Green']}

# %%
d
# Out:
# {'Fruits': ['Banana', 'Orange', 'Apple', 'Grapes'],
#  'Size': [20, 30, 40, 60],
#  'Weight': [80, 20, 40, 25],
#  'Color': ['Yellow', 'Orange', 'Red', 'Green']}

# %%
import pandas as pd
df=pd.DataFrame(d)

# %%
df
# Out:
#    Fruits  Size  Weight   Color
# 0  Banana    20      80  Yellow
# 1  Orange    30      20  Orange
# 2   Apple    40      40     Red
# 3  Grapes    60      25   Green

# %%
df.describe()
# Out:
#             Size     Weight
# count   4.000000   4.000000
# mean   37.500000  41.250000
# std    17.078251  27.195281
# min    20.000000  20.000000
# 25%    27.500000  23.750000
# 50%    35.000000  32.500000
# 75%    45.000000  50.000000
# max    60.000000  80.000000

# %%
x=10
if x==10:
    print("x is equal to 10")
# Out:
# x is equal to 10

# %%
x=10
if x>10:
    print("x is equal to 10")
else:
    print("x is not greater than 10")
# Out:
# x is not greater than 10

# %%
age=18
if age>=18:
    print("person is eligible for vote")
else:
    print("person is not eligible for vote")
# Out:
# person is eligible for vote

# %%
age=18
if age>18:
    print("person is eligible for vote")
else:
    print("person is not eligible for vote")
# Out:
# person is not eligible for vote

# %%
age=int(input("Enter the Age:="))
if age>=18:
    print("person is eligible for vote")
else:
    print("print is not eligible for vote")
# Out:
# Enter the Age:=18
# person is eligible for vote

# %%
x=int(input("Enter the first number:="))
y=int(input("Enter the second number:="))
z=int(input("Enter the third number:="))
if x>y and x>z:
    print("X is greatest among all")
elif y>z:
     print("Y is greatest among all")
else:
     print("Z is greatest among all")
# Out:
# Enter the first number:=12
# Enter the second number:=40
# Enter the third number:=60
# Z is greatest among all

# %%
a=int(input("Enter the first number:="))
b=int(input("Enter the second number:="))
c=int(input("Enter the third number:="))
d=int(input("Enter the fourth number:="))
e=int(input("Enter the fifth number:="))
if a>b and a>c and a>d and a>e:
    print("a is greatest among all")
elif b>c and b>d and b>e:
    print("b is greatest among all")
elif c>d and c>e:
    print("c is greatest among all")
else d>e:
    print("e is greatest among all")
# Out:
#   Cell In[4], line 12
#     else d>e:
#          ^
# SyntaxError: expected ':'

# %%
x=100 
if x>10:
    print("x is satisfied")
    if x>=50:
        print("abrdwsr")
    else:
        print("jiryhthhfrd")
# Out:
# x is satisfied
# abrdwsr

# %%
a=int(input("Enter the first number:="))
b=int(input("Enter the second number:="))
c=int(input("Enter the third number:="))
d=int(input("Enter the fourth number:="))
e=int(input("Enter the fifth number:="))
if a>b and a>c and a>d and a>e:
    print("A is greatest among all")
elif b>c and b>d and b>e:
    print("B is greatest among all")
elif c>d and c>e:
    print("C is greatest among all")
elif d>e:
    print("D is greatest among all")
else:
    print("E is greatest among all")
# Out:
# Enter the first number:=12
# Enter the second number:=30
# Enter the third number:=40
# Enter the fourth number:=48
# Enter the fifth number:=20
# D is greatest among all

# %%
x=100 
if x>10:
    print("x is satisfied")
    if x>=50:
        print("abrdwsr")
    else:
        print("jiryhthhfrd")
# Out:
# x is satisfied
# abrdwsr
