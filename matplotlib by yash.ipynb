# %%
#matplotlib

# %%
# !pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x=np.array([2,5,3,9])
plt.plot(x)
plt.show()

# %%
x=np.array([2,5,3,9])
y=np.array([5,2,6,7])
plt.plot(x,y)
plt.show()

# %%
x=np.array([2,5,3,9])
y=np.array([5,2,6,7])
plt.plot(x)
plt.plot(y)
plt.show()

# %%
x=np.array([2,5,3,9])
y=np.array([5,2,6,7])
plt.plot(x,"o")
plt.plot(y)
plt.show()

# %%
x=np.array([2,5,3,9])
y=np.array([5,2,6,7])
plt.plot(x,"o")
plt.plot(y,"*")
plt.show()

# %%
x=np.array([2,5,3,9])
plt.plot(x,"_")
plt.show()

# %%
x=np.array([2,5,3,9])
plt.plot(x,"o:r")
plt.show()

# %%
x=np.array([2,5,3,9])
plt.plot(x,"o:y")
plt.show()

# %%
x=np.array([2,5,3,9])
plt.plot(x,"o:b")
plt.show()

# %%
x=np.array([2,5,3,9])
plt.plot(x,marker="*",ms=30)
plt.show()

# %%
x=np.array([2,5,3,9])
plt.plot(x,marker="*",ms=30,mec="r")
plt.show()

# %%
x=np.array([2,5,3,9])
plt.plot(x,marker="*",ms=30,mec="r",mfc="g")
plt.show()

# %%
x=np.array([2,5,3,9])
plt.plot(x,marker="*",ms=30,mec="#F54927",mfc="black")
plt.show()

# %%
#linestyle

# %%
x=np.array([2,5,3,9])
plt.plot(x,marker="*",ms=30,mec="#F54927",mfc="black",ls="dotted")
plt.show()

# %%
x=np.array([2,5,3,9])
plt.plot(x,marker="*",ms=30,mec="#F54927",mfc="black",ls="dashdot")
plt.show()

# %%
x=np.array([2,5,3,9])
plt.plot(x,marker="*",ms=30,mec="#F54927",mfc="black",ls=":")
plt.show()

# %%
x=np.array([2,5,3,9])
plt.plot(x,marker="*",ms=30,mec="#F54927",mfc="black",ls="-",lw=10)
plt.show()

# %%
x=np.array([2,5,3,9])
plt.plot(x,marker="*",ms=30,mec="#F54927",mfc="black",ls=":",lw=10)
plt.show()

# %%
x=np.array([2,5,3,9])
plt.plot(x,marker="*",ms=30,mec="#F54927",mfc="black",ls="-",lw=10,color="r")
plt.show()

# %%
x=np.array([2,5,3,9])
plt.plot(x,marker="*",ms=30,mec="#F54927",mfc="black",ls="-",lw=10)
plt.xlabel("salary of employes")
plt.ylabel("experience of employes")
plt.show()

# %%
x=np.array([2,5,3,9])
plt.plot(x,marker="*",ms=30,mec="#F54927",mfc="black",ls="-",lw=10)
plt.xlabel("salary of employes")
plt.ylabel("experience of employes")
plt.title("salary vs experience")
plt.show()

# %%
x=np.array([2,5,3,9])
y=np.array([5,2,6,7])
font1={"family":"serif","color":"black","size":20}
font2={"family":"serif","color":"red","size":30}
plt.title("Experience vs Salary",fontdict=font1)
plt.xlabel("Salary",fontdict=font2)
plt.ylabel("Experience",fontdict=font2)
plt.plot(x,y)

# %%
x=np.array([2,5,3,9])
y=np.array([5,2,6,7])
font1={"family":"serif","color":"black","size":20}
font2={"family":"serif","color":"red","size":30}
plt.title("Experience vs Salary",fontdict=font1,loc="left")
plt.xlabel("Salary",fontdict=font2)
plt.ylabel("Experience",fontdict=font2)
plt.plot(x,y)

# %%
x=np.array([2,5,3,9])
y=np.array([5,2,6,7])
plt.plot(x,y,marker="*",ms=30,mec="#F54927",mfc="black",ls="-",lw=10,color="r")
plt.title("Experience vs Salary")
plt.xlabel("Salary")
plt.ylabel("Experience")
plt.show()

# %%
x=np.array([2,5,3,9])
y=np.array([5,2,6,7])
plt.plot(x,y,marker="*",ms=30,mec="#F54927",mfc="black",ls="-",lw=10,color="r")
plt.title("Experience vs Salary")
plt.xlabel("Salary")
plt.ylabel("Experience")
plt.grid()
plt.show()

# %%
x=np.array([2,5,3,9])
y=np.array([5,2,6,7])
plt.plot(x,y,marker="*",ms=30,mec="#F54927",mfc="black",ls="-",lw=10,color="r")
plt.title("Experience vs Salary")
plt.xlabel("Salary")
plt.ylabel("Experience")
plt.grid(axis="x")
plt.show()

# %%
x=np.array([2,5,3,9])
y=np.array([5,2,6,7])
plt.plot(x,y,marker="*",ms=30,mec="#F54927",mfc="black",ls="-",lw=10,color="r")
plt.title("Experience vs Salary")
plt.xlabel("Salary")
plt.ylabel("Experience")
plt.grid(color="b",lw=4,ls="dotted")
plt.show()

# %%
x=np.array([2,5,3,9])
y=np.array([5,2,6,7])
plt.plot(x,y,marker="*",ms=30,mec="#F54927",mfc="black",ls="-",lw=10,color="r")
plt.title("Experience vs Salary")
plt.xlabel("Salary")
plt.ylabel("Experience")
plt.grid(color="b",lw=4,ls="dotted",which="major",mec="m")
plt.show()

# %%
x=np.array([2,5,3,9,8,5,4,2,6,7,2,0])
y=np.array([5,2,6,7,4,0,2,1,9,5,7,6])
plt.scatter(x,y)

# %%
x=np.array([2,5,3,9,8,5,4,2,6,7,2,0])
y=np.array([5,2,6,7,4,0,2,1,9,5,7,6])
plt.scatter(x,y)
x=np.array([2,5,33,9,84,95,43,2,65,7,2,10])
y=np.array([58,2,61,7,41,0,45,1,9,55,7,36])
plt.scatter(x,y)

# %%
x=np.array([2,5,3,9])
y=np.array([5,2,6,7])
colors=np.array(["red","blue","green","orange"])
plt.scatter(x,y,c=colors)

# %%
x=np.array([2,5,3,9,8,5,4,2,6,7,2,0])
y=np.array([5,2,6,7,4,0,2,1,9,5,7,6])
colors=np.array([10,20,30,40,45,50,60,65,70,75,80,90])
plt.scatter(x,y,c=colors,cmap="viridis")

# %%
x=np.array([2,5,3,9,8,5,4,2,6,7,2,0])
y=np.array([5,2,6,7,4,0,2,1,9,5,7,6])
colors=np.array([10,20,30,40,45,50,60,65,70,75,80,90])
plt.scatter(x,y,c=colors,cmap="viridis")
plt.colorbar()

# %%
x=np.array([2,5,3,9,8,5,4,2,6,7,2,0])
y=np.array([5,2,6,7,4,0,2,1,9,5,7,6])
colors=np.array([10,20,30,40,45,50,60,65,70,75,80,90])
sizes=np.array([40,50,400,30,49,220,223,300,80,601,754,133])
plt.scatter(x,y,c=colors,cmap="viridis",s=sizes)
plt.colorbar()

# %%
x=np.array([2,5,3,9,8,5,4,2,6,7,2,0])
y=np.array([5,2,6,7,4,0,2,1,9,5,7,6])
colors=np.array([10,20,30,40,45,50,60,65,70,75,80,90])
sizes=np.array([40,50,400,30,49,220,223,300,80,601,754,133])
plt.scatter(x,y,c=colors,cmap="viridis",s=sizes,alpha=0.5)
plt.colorbar()

# %%
x=np.array([2,5,3,9,8,5,4,2,6,7,2,0])
y=np.array([5,2,6,7,4,0,2,1,9,5,7,6])
colors=np.array([10,20,30,40,45,50,60,65,70,75,80,90])
sizes=np.array([40,50,400,30,49,220,223,300,80,601,754,133])
plt.scatter(x,y,c=colors,cmap="viridis",s=sizes,alpha=0.2)
plt.colorbar()

# %%
x=np.array([2,5,3,9,8,5,4,2,6,7,2,0])
y=np.array([5,2,6,7,4,0,2,1,9,5,7,6])
colors=np.array([10,20,30,40,45,50,60,65,70,75,80,90])
sizes=np.array([40,50,400,30,49,220,223,300,80,601,754,133])
plt.scatter(x,y,c=colors,cmap="nipy_spectral",s=sizes,alpha=0.2)
plt.colorbar()

# %%
import matplotlib.pyplot as plt
#create a 2*2 grid of subplots
fig,axs=plt.subplots(2,2)
#Plot on each subplot
axs[0,1].bar ([1,2,3],[4,5,6])
axs[0,1].set_title ('Plot 2')
plt.tight_layout()
plt.show()

# %%
#Data for the polar plot 
theta=np.linspace(0,2*np.pi,100)
r=np.sin(theta) #Example of periodic data 
#Create a polar plot 
plt.subplot(projection='polar')
plt.plot(theta,r)
plt.title('Polar Plot')
plt.show()

# %%
#Plot data 
x=[1,2,3,4,5]
y=[2,3,5,7,11]
plt.plot(x,y)
#Annotate a specific point 
plt.annotate ('Prime number',xy=(3,5),xytext=(4,6),
arrowprops=dict(facecolor='red',arrowstyle='->'))
plt.title('Annotated Plot')
plt.show()

# %%
#Create random data 
data=np.random.rand(10,10)
#Create a heatmap
plt.imshow(data,cmap='viridis',interpolation='nearest')
plt.colorbar()  #Show color scale
plt.title('Heatmap')
plt.show()

# %%
#Create random data 
data=np.random.rand(100,200)
#Create a heatmap
plt.imshow(data,cmap='viridis',interpolation='nearest')
plt.colorbar()  #Show color scale
plt.title('Heatmap')
plt.show()

# %%
#Create random data 
data=np.random.rand(10,10)
#Create a heatmap
plt.imshow(data,cmap='pink',interpolation='nearest')
plt.colorbar()  #Show color scale
plt.title('Heatmap')
plt.show()

# %%
labels=['A','B','C','D']
sizes=[15,30,45,10]
plt.pie(sizes,labels=labels,autopct='%1.1f%%')
plt.title('Basic Pie Chart')
plt.show()

# %%
labels=['A','B','C','D']
sizes=[155,300,145,100]
plt.pie(sizes,labels=labels,autopct='%1.1f%%')
plt.title('Basic Pie Chart')
plt.show()

# %%
plt.plot(x,y,linestyle='--',color='red',marker='o')
plt.title('Customized Line Plot')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
plt.plot(x,y,linestyle='--',color='black',marker='o')
plt.title('Customized Line Plot')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
