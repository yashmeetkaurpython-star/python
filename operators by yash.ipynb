# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
x=int(input("Enter the value of x:"))
y=int(input("Enter the value of y:"))
print("the Addition of x&y is:",x+y)
print("the Subtraction of x&y is:",x-y)
print("the Multiplication of x&y is:",x*y)
print("the Division of x&y is:",x/y)
print("the Floor division of x&y is:",x//y)
print("the Exponentiation of x&y is:",x**y)
print("the Modulus of x&y is:",x%y)
# Out:
# Enter the value of x:5
# Enter the value of y:50
# the Addition of x&y is: 55
# the Subtraction of x&y is: -45
# the Multiplication of x&y is: 250
# the Division of x&y is: 0.1
# the Floor division of x&y is: 0
# the Exponentiation of x&y is: 88817841970012523233890533447265625
# the Modulus of x&y is: 5

# %%
x=5
x=x+3
print(x)
# Out:
# 8

# %%
x=2
x=x-3
print(x)
# Out:
# -1

# %%
x=4
x=x*3
print(x)
# Out:
# 12

# %%
x=6
x=x/3
print(x)
# Out:
# 2.0

# %%
x=8
x=x//3
print(x)
# Out:
# 2

# %%
x=10
x=x%3
print(x)
# Out:
# 1

# %%
x=5
x=x&3
print(x)
# Out:
# 1

# %%
x=7
x=x|3
print(x)
# Out:
# 7

# %%
x=4
x=x^3
print(x)
# Out:
# 7

# %%
x=5
x=x>>3
print(x)
# Out:
# 0

# %%
x=5
x=x<<3
print(x)
# Out:
# 40

# %%
x=15
y=30
print(x==y)
# Out:
# False

# %%
x=70
y=90
print(x<=y)
# Out:
# True

# %%
x=90
y=120
print(x>=y)
# Out:
# False

# %%
x=20
y=20
print(x!=y)
# Out:
# False

# %%
x=20
y=20
print(x and y)
# Out:
# 20

# %%
x=20
y=30
if x==50 and y==30:
      print("true")
else: 
       print("false")
# Out:
# false

# %%
x=90 
y=120 
if x==90 and y==120:
       print("true")
else: 
       print("false")
# Out:
# true

# %%
x=12
y=2
if x==12 or y==2:
       print("true")
else: 
       print("false")
# Out:
# true

# %%
x=True
print(not x)
# Out:
# False

# %%
X=2
X=X<<3
print(x<<3)
# Out:
# 56

# %%
x=10
y=10
print(x==y)
print(x is y)
# Out:
# True
# True

# %%
x=256
y=256
print(x==y)
print(x is y)
print(id(x))
print(id(y))
# Out:
# True
# True
# 8893160
# 8893160

# %%
x=257
y=257
print(x==y)
print(x is y)
print(id(x))
print(id(y))
# Out:
# True
# False
# 140488410078512
# 140488410082608

# %%
x=[5,4,3,4,2,10000]
l=10000
l in x
# Out:
# True

# %%
x=[2,5,7,1,9,3,0]
l=0
l in x
# Out:
# True
