# %%
s={}
s1={1}
print (type(s))
print(type(s1))
# Out:
# <class 'dict'>
# <class 'set'>

# %%
s={"name":"yash"}
s1={1,2,4,5,7}
print (type(s))
print(type(s1))
# Out:
# <class 'dict'>
# <class 'set'>

# %%
#set contain variety of data in a single variable
s={1,2,3,4,9,0,3,"yash",2,5,1,7,0}

# %%
s
# Out:
# {0, 1, 2, 3, 4, 5, 7, 9, 'yash'}

# %%
#set is unordered,unchanged,unixdexed,
#does not allows duplicate

# %%
#unordered
s1={7,6,5,8,3,9,2,0,1,}
print(s1)
# Out:
# {0, 1, 2, 3, 5, 6, 7, 8, 9}

# %%
#not allows duplicate 
s2={6,4,3,7,6,4,2,8,5,9,2,0}
print(s2)
# Out:
# {0, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
#unindexed
s3={6,8,2,4,6,3,1,0,1,0}
print(s3)
# Out:
# {0, 1, 2, 3, 4, 6, 8}

# %%
s3[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 s3[2]
#
# TypeError: 'set' object is not subscriptable

# %%
s4={5,2,4,True,4,1,0,8,9,False}
print(s4)
# Out:
# {0, True, 2, 4, 5, 8, 9}

# %%
s4[5]="yash"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 s4[5]="yash"
#
# TypeError: 'set' object does not support item assignment

# %%
#set Methods

# %%
s5={5,True,False,5,"yash","dilpreet",7,8,5,6}

# %%
s5.add("khipal")

# %%
print (s5)
# Out:
# {False, True, 5, 6, 7, 'dilpreet', 8, 'yash', 'khipal'}

# %%
s5
# Out:
# {5, 6, 7, 8, False, True, 'dilpreet', 'khipal', 'yash'}

# %%
x=s5.copy()
print(x)
# Out:
# {False, True, 5, 6, 7, 'dilpreet', 8, 'yash', 'khipal'}

# %%
s5.discard("dilpreet")
print(s5)
# Out:
# {False, True, 5, 6, 7, 8, 'yash', 'khipal'}

# %%
s={4,5,6,8,9,2,1,32}
s1={"khipal",5,8,3,4,6}

# %%
print(s.discard(9))
print(s1.remove("khipal"))
# Out:
# None
# None

# %%
s={4,5,6,8,9,2,1,32}
s1={"khipal",5,8,3,4,6}

# %%
s.discard(9)

# %%
s
# Out:
# {1, 2, 4, 5, 6, 8, 32}

# %%
s1.remove("khipal")

# %%
s1
# Out:
# {3, 4, 5, 6, 8}

# %%
s1.remove("khipal")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 s1.remove("khipal")
#
# KeyError: 'khipal'

# %%
s1.discard("khipal")

# %%
s1
# Out:
# {3, 4, 5, 6, 8}

# %%
s={5,4,3,1}
s1={4,8,1,2}

# %%
s.difference(s1)
# Out:
# {3, 5}

# %%
s
# Out:
# {1, 3, 4, 5}

# %%
s.difference_update(s1)

# %%
s
# Out:
# {3, 5}

# %%
s={5,4,3,1}
s1={4,8,1,2}

# %%
s.intersection(s1)
# Out:
# {1, 4}

# %%
s
# Out:
# {1, 3, 4, 5}

# %%
s.intersection_update(s1)

# %%
s
# Out:
# {1, 4}

# %%
s={5,4,3,1}
s1={4,8,1,2}

# %%
s
# Out:
# {1, 3, 4, 5}

# %%
s1
# Out:
# {1, 2, 4, 8}

# %%
s.isdisjoint(s1)
# Out:
# False

# %%
s.issubset(s1)
# Out:
# False

# %%
s={1,5,6,8,9,7,4}
s1={5,9,7,6}

# %%
s1.issubset(s)
# Out:
# True

# %%
s.issuperset(s1)
# Out:
# True

# %%
s.pop()
# Out:
# 1

# %%
s
# Out:
# {4, 5, 6, 7, 8, 9}

# %%
s={1,5,6,8,9,7,4}
s1={5,9,7,6}
s.symmetric_difference(s1)
# Out:
# {1, 4, 8}

# %%
s
# Out:
# {1, 4, 5, 6, 7, 8, 9}

# %%
s={1,5,6,8,9,7,4}
s1={5,9,7,6}
s.symmetric_difference_update(s1)

# %%
s
# Out:
# {1, 4, 8}

# %%
s={1,5,6,8,9,7,4}
s1={5,9,10,6,16,47}

# %%
s.union(s1)
# Out:
# {1, 4, 5, 6, 7, 8, 9, 10, 16, 47}

# %%
s
# Out:
# {1, 4, 5, 6, 7, 8, 9}

# %%
s.update(s1)

# %%
s
# Out:
# {1, 4, 5, 6, 7, 8, 9, 10, 16, 47}

# %%
str1='abc'
print(str1)
# Out:
# abc

# %%
string1='abc'
print(string1)
# Out:
# abc

# %%
str2='123'
print(str2)
# Out:
# 123

# %%
str3=str1+str2
print(str3)
# Out:
# abc123

# %%
str4=str3+1
print(str4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 str4=str3+1
#       2 print(str4)
#
# TypeError: can only concatenate str (not "int") to str

# %%
str3='123'
str4=int(str3)+1
print(str4)
# Out:
# 124

# %%
name='yash'
len(name)
print(len(name))
# Out:
# 4

# %%
s='data visualization'
print(s[0:4])
print(s[:])
print(s[7:20])
# Out:
# data
# data visualization
# sualization

# %%
print(s[:20])
# Out:
# data visualization

# %%
print(s[9:])
# Out:
# alization

# %%
s='data visualization'
'v'in s
# Out:
# True

# %%
s='data visualization'
'm' in s
# Out:
# False

# %%
a=s.find('al')
print(a)
# Out:
# 9

# %%
a=s.find('a')
print(a)
# Out:
# 1

# %%
a=s.find('b')
print(a)
# Out:
# -1

# %%
b=s.upper()
print(b)
# Out:
# DATA VISUALIZATION

# %%
b=s.lower()
print(b)
# Out:
# data visualization

# %%
c=s.replace('visualization','analytics')
print(c)
# Out:
# data analytics
