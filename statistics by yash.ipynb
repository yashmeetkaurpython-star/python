# %%
import numpy as np

# %%
data=[4,12,5,8,6,16,4,50,88,45,10,12,13,45,16,18,19,20,22,25,82]
len(data)
# Out:
# 21

# %%
x=np.mean(data)
print(x)
# Out:
# 24.761904761904763

# %%
z=data.sort()

# %%
print(data)
# Out:
# [4, 4, 5, 6, 8, 10, 12, 12, 13, 16, 16, 18, 19, 20, 22, 25, 45, 45, 50, 82, 88]

# %%
data=[4,12,5,8,6,16,4,50,88,45,10,12,13,45,16,18,19,20,22,25,82]
x=np.median(data)
print(x)
# Out:
# 16.0

# %%
from scipy import stats
data=[4,12,5,8,6,16,4,50,88,45,10,12,13,45,16,18,19,20,22,25,82]
x=stats.mode(data)
print(x)
# Out:
# ModeResult(mode=4, count=2)

# %%
data=[2,4,3,6,7,10,3,9,2,1]
x=np.var(data)
print(x)
# Out:
# 8.809999999999999

# %%
np.std(data)
# Out:
# 2.9681644159311658
